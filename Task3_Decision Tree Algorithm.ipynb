# %% [markdown]
# # Task_3 : Prediction using Decision Tree Algorithm.
#
# ### For the given ‘Iris’ dataset, create the Decision Tree classifier and visualize it graphically.

# %% [markdown]
# # Submitted : by Aman Husain
#
# # Decision Tree Algorithm

# %% [markdown]
# ## Importing all the required libraries

# %%
#Import all required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading the Iris Data

# %%
# Loading the Iris Data
df=pd.read_csv("iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Information about the Data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Describe the Data
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## Visualize the Data

# %%
# Scatter plot between SepalLength and SepalWidth
df.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")
plt.title("SepalLength Vs SepalWidth")
plt.grid()

# %%
sns.jointplot(x = "SepalLengthCm", y = "SepalWidthCm", data = df, size = 8)
# Out:
# C:\Users\N.K laptop Solution\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2264: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Boxplot

# %%
# Boxplot Betweeb Species and PetalLength
sns.boxplot(x = "Species", y = "PetalLengthCm", data = df)

# %%
# Boxplot Between Species and PetalWidth
sns.boxplot(x = "Species", y = "PetalWidthCm", data = df)

# %%
# Boxplot between Species and SepalLength
sns.boxplot(x = "Species", y = "SepalLengthCm", data = df)

# %%
# Boxplot between Species and SepaWidth 
sns.boxplot(x = "Species", y = "SepalWidthCm", data = df)

# %%
# Initializing the Data
x=df.iloc[:, 1:5]
y=df.iloc[:, -1]

# %%
#Splitting the Data into train and test
xtrain,xtest,ytrain,ytest,=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ### Initializing the Model

# %%
model=dtc()
md=model.fit(xtrain,ytrain)

# %% [markdown]
# ### Predicting the values

# %%
ypred=model.predict(xtest)
ypred_train=model.predict(xtrain)

# %% [markdown]
# ### Accuracy of the Model

# %%
accuracy_score(ypred,ytest)*100
# Out:
# 96.66666666666667

# %%
accuracy_score(ytrain,ypred_train)*100
# Out:
# 100.0

# %%
ypred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor'], dtype=object)

# %% [markdown]
# ## Let us Visualizing the Decision Tree to understand it better

# %%
from sklearn import tree

# %%
plt.figure(figsize=(20,18))
tree.plot_tree(model,feature_names=df.keys()[:-1], class_names=["Iris-Setosa", "Iris-versicolor", "Iris-verginica"],
                                          filled=True, rounded=True, fontsize=20)
plt.show()
